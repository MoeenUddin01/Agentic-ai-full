# %%
print("Cell 0")
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")
# Out:
# Cell 0

# %%
#Tool internet search
print("cell 1")
from typing import Literal
from tavily import TavilyClient

tavily_client=TavilyClient(api_key=("tavily_api_key"))

def web_search(query:str,max_results:int=5,topic:Literal["general","news","finance"]="general",include_raw_content:bool=False):
    """
    Search the web using Tavily API
    """
    response = tavily_client.search(query=query,max_results=max_results,topic=topic,include_raw_content=include_raw_content)
    return response
# Out:
# cell 1

# %%
print("Cell 2")
from langchain.chat_models import init_chat_model

groq_model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")
print(groq_model)
# Out:
# Cell 2
# metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11'}} output_version=None profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True} client=<groq.resources.chat.completions.Completions object at 0x70ca39eee630> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x70ca39eefd70> model_name='llama-3.3-70b-versatile' model_kwargs={} groq_api_key=SecretStr('**********') groq_api_base=None groq_proxy=None

# %%
print("Cell 3")
##create a deep agent
from deepagents import create_deep_agent
from langchain.tools import tool



deepagent=creat_deep_agent = create_deep_agent(
    tool=[web_search],
    model=qroq_model,
    system_prompt="You are a researcher"
   
)
deepagent
# Out:
# Cell 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       6
#       7
#       8 deepagent=creat_deep_agent = create_deep_agent(
#       9     tool=[web_search],
# ---> 10     model=qroq_model,
#      11     system_prompt="You are a researcher"
#      12
#      13 )
#
# NameError: name 'qroq_model' is not defined

# %%
print("Cell 4")
#normal agent
#basic agent
from langchain.agents import create_agent

simple_agent=create_agent(
    model=model
)
