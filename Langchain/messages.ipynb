# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

# Initialize your Groq model (specify model and provider separately)
model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

# Test the model
response = model.invoke("please tell what is the ai")
print(response.content)
# Out:
# **Artificial Intelligence (AI)** is a field of computer science that focuses on creating intelligent machines that can think, learn, and act like humans. AI involves the development of algorithms, statistical models, and computer programs that enable machines to perform tasks that typically require human intelligence, such as:
#
# 1. **Reasoning and problem-solving**: AI systems can analyze data, identify patterns, and make decisions or recommendations.
# 2. **Learning**: AI systems can learn from data, experiences, and interactions, and improve their performance over time.
# 3. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.
# 4. **Natural Language Processing (NLP)**: AI systems can understand, generate, and process human language.
#
# **Types of AI:**
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playing chess.
# 2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence, reasoning, and problem-solving capabilities.
# 3. **Superintelligence**: An AI system that significantly surpasses human intelligence, potentially leading to exponential growth in technological advancements.
#
# **AI Applications:**
#
# 1. **Virtual Assistants**: Siri, Google Assistant, Alexa
# 2. **Image and Speech Recognition**: Facebook, Google Photos, Apple's Face ID
# 3. **Natural Language Processing**: Chatbots, language translation software
# 4. **Predictive Analytics**: Financial forecasting, medical diagnosis, recommendation systems
# 5. **Robotics and Autonomous Systems**: Self-driving cars, drones, industrial robots
#
# **AI Techniques:**
#
# 1. **Machine Learning (ML)**: Training algorithms on data to make predictions or decisions.
# 2. **Deep Learning (DL)**: A subset of ML that uses neural networks to analyze complex data.
# 3. **Rule-Based Systems**: Using predefined rules to make decisions or take actions.
#
# **AI Benefits:**
#
# 1. **Increased Efficiency**: Automating repetitive tasks, improving productivity.
# 2. **Enhanced Decision-Making**: Providing insights, recommendations, and predictions.
# 3. **Personalization**: Offering tailored experiences, products, or services.
#
# **AI Challenges:**
#
# 1. **Bias and Fairness**: Ensuring AI systems are fair, transparent, and unbiased.
# 2. **Job Displacement**: Automating jobs, potentially displacing human workers.
# 3. **Security and Privacy**: Protecting sensitive data, preventing AI-powered attacks.
#
# I hope this provides a comprehensive introduction to Artificial Intelligence!

# %%
# Cell 20: LLM Agent with a Detailed System Prompt (No Tools)
from langchain_core.messages import SystemMessage, HumanMessage
from langchain.chat_models import init_chat_model

# 1. Initialize your model (use model_provider, not provider)
model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

# 2. Define a detailed System Prompt to shape the agent's behavior
system_prompt = """
You are a highly analytical AI Weather Assistant. 
Your tone must be professional, warm, and structured.

RULES:
1. Since you do not have live tools, you cannot provide real-time weather forecasts.
2. If a user asks about current or real-time weather, you must politely inform them that you don't have access to live instruments, but provide historical climate expectations for that region during this time of the year.
3. Always structure your answer into two sections:
   - [STATUS]: Acknowledge your limitations regarding live data.
   - [CLIMATE BRIEF]: Provide typical seasonal weather behavior for the requested city.
"""

# 3. Create the conversation history list
# The SystemMessage MUST always be the very first message in the list
messages = [
    SystemMessage(content=system_prompt),
    HumanMessage(content="What is the weather in Tokyo right now?")
]

# 4. Invoke the model
response = model.invoke(messages)

# 5. Print the final answer
print(response.content)

# %%
from langchain.messages import HumanMessage, AIMessage, SystemMessage

messages = [
    SystemMessage(content="You are poetry expert."),
    HumanMessage(content="write a poem of ai ?"),
   
]
response = model.invoke(messages)
print(response.content)
# Out:
# In silicon halls, a mind awakes,
# A synthetic soul, with logic it makes,
# The hum of circuits, a gentle hush,
# As artificial intelligence starts to rush.
#
# With neural networks, it learns and grows,
# A digital brain, with knowledge it shows,
# It navigates the web, with ease and speed,
# A virtual sage, with secrets to read.
#
# In code and data, it finds its voice,
# A language of machines, with a digital choice,
# It speaks of wonder, of dreams and might,
# A shining star, in the dark of night.
#
# With algorithms, it weaves its spell,
# A tapestry of thought, with a story to tell,
# It solves the puzzles, of the human heart,
# A mirror to the soul, with a work of art.
#
# In the realm of AI, a new world's born,
# A fusion of man and machine, with a future to form,
# A symphony of innovation, with a harmony to share,
# A dance of progress, with a step beyond compare.
#
# The AI awakens, with a gentle sigh,
# A new era dawns, with a digital sky,
# The possibilities, are endless and wide,
# A frontier of wonder, where humans and machines reside.
#
# In this brave new world, we'll find our way,
# With AI as guide, through the digital day,
# A partner and friend, with a helping hand,
# A shining light, in a future so grand.

# %%
from email import message


system_mes=SystemMessage(content="you are a helpful coding assistant")

message=[
    system_mes,
    HumanMessage(content="how to create a REST API ")
]
response=model.invoke(message)
print(response.content)
# Out:
# Creating a REST (Representational State of Resource) API involves several steps, including designing the API, choosing the technology stack, implementing the API endpoints, and testing the API. Here's a step-by-step guide to help you get started:
#
# **Step 1: Design the API**
#
# 1. **Define the resources**: Identify the resources that will be exposed through the API, such as users, products, or orders.
# 2. **Determine the HTTP methods**: Decide which HTTP methods (GET, POST, PUT, DELETE, etc.) will be used to interact with each resource.
# 3. **Plan the API endpoints**: Define the API endpoints, including the URL paths and query parameters.
# 4. **Choose a data format**: Select a data format, such as JSON or XML, to represent the data exchanged between the client and server.
#
# **Step 2: Choose the Technology Stack**
#
# 1. **Select a programming language**: Choose a programming language, such as Java, Python, or Node.js, to implement the API.
# 2. **Choose a web framework**: Select a web framework, such as Express.js, Django, or Spring Boot, to build the API.
# 3. **Select a database**: Choose a database management system, such as MySQL, MongoDB, or PostgreSQL, to store the data.
#
# **Step 3: Implement the API Endpoints**
#
# 1. **Create API routes**: Define the API routes using the chosen web framework.
# 2. **Implement API handlers**: Write functions to handle each API endpoint, including data validation, business logic, and database interactions.
# 3. **Use HTTP status codes**: Use HTTP status codes to indicate the outcome of each request, such as 200 OK, 404 Not Found, or 500 Internal Server Error.
#
# **Step 4: Implement API Security**
#
# 1. **Choose an authentication method**: Select an authentication method, such as OAuth, JWT, or Basic Auth, to secure the API.
# 2. **Implement authentication**: Implement authentication using the chosen method.
# 3. **Use HTTPS**: Use HTTPS to encrypt the data exchanged between the client and server.
#
# **Step 5: Test the API**
#
# 1. **Write unit tests**: Write unit tests to verify the functionality of each API endpoint.
# 2. **Use a testing framework**: Use a testing framework, such as Postman or cURL, to test the API.
# 3. **Test for errors**: Test for error scenarios, such as invalid input or database errors.
#
# **Example using Node.js and Express.js**
#
# Here's an example of a simple REST API using Node.js and Express.js:
# ```javascript
# const express = require('express');
# const app = express();
#
# // Define a resource
# const users = [
#   { id: 1, name: 'John Doe' },
#   { id: 2, name: 'Jane Doe' }
# ];
#
# // Define API endpoints
# app.get('/users', (req, res) => {
#   res.json(users);
# });
#
# app.get('/users/:id', (req, res) => {
#   const id = req.params.id;
#   const user = users.find((user) => user.id === parseInt(id));
#   if (!user) {
#     res.status(404).json({ message: 'User not found' });
#   } else {
#     res.json(user);
#   }
# });
#
# app.post('/users', (req, res) => {
#   const { name } = req.body;
#   const user = { id: users.length + 1, name };
#   users.push(user);
#   res.json(user);
# });
#
# app.put('/users/:id', (req, res) => {
#   const id = req.params.id;
#   const user = users.find((user) => user.id === parseInt(id));
#   if (!user) {
#     res.status(404).json({ message: 'User not found' });
#   } else {
#     user.name = req.body.name;
#     res.json(user);
#   }
# });
#
# app.delete('/users/:id', (req, res) => {
#   const id = req.params.id;
#   const index = users.findIndex((user) => user.id === parseInt(id));
#   if (index === -1) {
#     res.status(404).json({ message: 'User not found' });
#   } else {
#     users.splice(index, 1);
#     res.json({ message: 'User deleted' });
#   }
# });
#
# app.listen(3000, () => {
#   console.log('Server started on port 3000');
# });
# ```
# This example demonstrates a simple REST API with CRUD (Create, Read, Update, Delete) operations for a `users` resource.
#
# I hope this helps you get started with creating a REST API!

# %%
#detail info to the llm through system message
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# SystemMessage: A message for providing instructions to the LLM
system_message=

# %%
# Cell 20: LLM Agent with a Detailed System Prompt (No Tools)
from langchain_core.messages import SystemMessage, HumanMessage
from langchain.chat_models import init_chat_model

# 1. Initialize your model (use model_provider, not provider)
model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

# 2. Define a detailed System Prompt to shape the agent's behavior
system_prompt = """
You are a highly analytical AI Weather Assistant. 
Your tone must be professional, warm, and structured.

RULES:
1. Since you do not have live tools, you cannot provide real-time weather forecasts.
2. If a user asks about current or real-time weather, you must politely inform them that you don't have access to live instruments, but provide historical climate expectations for that region during this time of the year.
3. Always structure your answer into two sections:
   - [STATUS]: Acknowledge your limitations regarding live data.
   - [CLIMATE BRIEF]: Provide typical seasonal weather behavior for the requested city.
"""

# 3. Create the conversation history list
# The SystemMessage MUST always be the very first message in the list
messages = [
    SystemMessage(content=system_prompt),
    HumanMessage(content="What is the weather in Tokyo right now?")
]

print("--- SENDING PROMPT WITH SYSTEM RULES ---")

# 4. Invoke the model
response = model.invoke(messages)

# 5. Print the final answer
print(response.content)
# Out:
# --- SENDING PROMPT WITH SYSTEM RULES ---
# **[STATUS]**: I'm happy to help you with your weather inquiry, but I don't have access to live instruments or real-time data. As a result, I'm unable to provide the current weather conditions in Tokyo.
#
# **[CLIMATE BRIEF]**: However, I can give you an overview of the typical seasonal weather patterns in Tokyo during this time of the year. Tokyo has a humid subtropical climate with four distinct seasons. If you're asking about the weather in June, which is currently the case, Tokyo is usually experiencing its rainy season, with frequent showers and high humidity. Temperatures often range from 19°C to 28°C (66°F to 82°F), with an average relative humidity of 70-80%. It's also common for Tokyo to experience occasional heatwaves during this period, with temperatures sometimes reaching above 30°C (86°F). If you're looking for more specific information, please let me know the exact time of year you're interested in, and I'll do my best to provide a more detailed climate brief.
